# %% [markdown]
# # <span style="color:darkblue"> Lecture 2: Objects, Variables and Lists </span>

# %% [markdown]
# <font size="5">
#
# In this notebook we will:
#
# - Introduce "objects" and their corresponding data types
# - Learn how to assign values to **variables**
# - Cover **lists** - which are collections of objects

# %% [markdown]
# # <span style="color:darkblue"> 1. Objects and Data Types </span>

# %% [markdown]
# ## Almost everything in Python is an "object"
# - ### The built-in number " 3 " is an object
# - ### The phrase " "Hello World!" " is an object. (The number of quotation marks I typed is intentional)
# - ### Each object has a **type** (or a **class**)

# %% [markdown]
# ### Some common object types are
# * ### Integers (int): "Whole numbers" including zero and negatives
# * ### Floating-point numbers (float): Numbers with decimals
# * ### Strings (str): A sequence of characters representing text.
#
#
# ### We can use the built-in Python function "type" to see what an object's type is. We pass the object as an "argument" (or input) to the function.

# %%
type(3)
# Out:
# int

# %%
type(3.25)
# Out:
# float

# %%
type("Hello World!")
# Out:
# str

# %% [markdown]
# ### Use the "print" function if you want a single code cell to print out multiple things:

# %%
type(3) # doesn't get printed
type(3.25) # doesn't get printed
type("Hello World!") # gets printed
# Out:
# str

# %%
print(type(3))
print(type(3.25))
print(type("Hello World!"))
print(type(True))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# #### (but the formatting of the printing might be a little different)

# %%
# You can define strings with either single or double quotations.
type('Hello World!')
# Out:
# str

# %%
# But you can't mix single and double quotes:
type("Hello World!")
# Out:
# str

# %%
# The flexibility of using either single or double quotes is useful when you want to include 
# a quote character inside a string.
print("Today's lecture is about Jupyter notebooks.")
print('In Python, "classes" and "types" are essentially synonymous.')
print() # prints a blank line
# use both single and double quotes in the same string by adding a backslash in front
print('In today\'s lecture we learned that "classes" and "types" are essentially synonymous.')
print("In today's lecture we learned that \"classes\" and \"types\" are essentially synonymous.")
# Out:
# Today's lecture is about Jupyter notebooks.
# In Python, "classes" and "types" are essentially synonymous.
#
# In today's lecture we learned that "classes" and "types" are essentially synonymous.
# In today's lecture we learned that "classes" and "types" are essentially synonymous.

# %%
# Another common type is "built-in functions"
type(print)
# Out:
# builtin_function_or_method

# %%
import math
print(type(math.sqrt))
print(type(math.sqrt(3)))
# Out:
# <class 'builtin_function_or_method'>
# <class 'float'>

# %% [markdown]
# # <span style="color:darkblue"> 2. Variables </span>

# %% [markdown]
# * ### We usually want to use **variables**, which is "a name that refers to a value".
# * ### Another way to think about it: a variable is a "named storage location" where we save values for later use
# * ### Variables can be created using the **assignment operator** "="
# * ### **WARNING**: in Python, "=" is NOT the "equals sign". It is the **assignment operator**

# %% [markdown]
# ### Put your hand over your heart and repeat these words: "**I will not call the assignment operator an equal sign**"
# (Actually, it common to call it an "equal sign" when informally discussing code. I do this too, I am just trying to drive the point home)

# %%
x = 3
y = 3.25
# Out:
# <class 'float'>

# %% [markdown]
# ## What happened in the above code cell?
# ### 1. We took the built-in number 3 (an integer) and **assigned** this value to a new variable, called "x"
# ### 2. We took the built-in number 3.25 (a float) and **assigned** this value to a new variable, called "y"
#
# #### Notice I did **not** say 'we created a variable called "x" and gave it the value 3'. Everything to the right of "=" happens first.

# %%
# you can check the type of a variable after you define it:
print(type(x))
print(type(y))
# Out:
# <class 'int'>
# <class 'float'>

# %% [markdown]
# ### Or, you can click "Jupyter Variables" in the top panel of the notebook to see the variables that have been created

# %%
# Consider the following block of code:
z = 6
print(z)
z = z + 1
print(z)

# What do you think will be printed?

# How should we interpret what happened?
# Out:
# 6
# 7

# %% [markdown]
# ### This is not an algebra class, we do not have to call our variables "x,y,z, etc."
# * ### Variable names can include letters (A-Z) and (a-z), numbers (0-9), and the underscore character "_"
# * ### Variable names cannot start with a number
# * ### For readable code, choose **descriptive** variable names

# %% [markdown]
# ### Question: A vinyl record costs $32.99. The sales tax in Fulton County is 8.9%, while the sales tax in DeKalb County is 8%. How much more would you pay if you purchased it in DeKalb county?

# %%
record_price = 32.99
fulton_tax_rate = 0.089
dekalb_tax_rate = 0.08

fulton_cost = record_price + (record_price * fulton_tax_rate)
dekalb_cost = record_price + record_price * dekalb_tax_rate

price_difference = fulton_cost - dekalb_cost
print(price_difference)
# Out:
# 0.2969099999999969

# %%
# When calculating the price after sales tax, stores typically round to the nearest cent.

record_price = 32.99
fulton_tax_rate = 0.089
dekalb_tax_rate = 0.08

fulton_cost = record_price + record_price * fulton_tax_rate
# round to 2 decimal places
fulton_cost = round(fulton_cost, 2) 

dekalb_cost = record_price + record_price * dekalb_tax_rate
dekalb_cost = round(dekalb_cost, 2) # round to 2 decimal places

price_difference = fulton_cost - dekalb_cost
print(price_difference) # ?????

# even though we have already rounded to 2 digits, must do it again because
# Python uses binary floating-point arithmetic.

price_difference = round(price_difference, 2)
print(price_difference)
# Out:
# 0.29999999999999716
# 0.3

# %% [markdown]
# ### Variables do not have to be numbers

# %%
first_name = "Nathan"
last_name = 'Gabriel'
course = "DSci 160 - Fall 2026"

print(first_name)
print(type(first_name))
# Out:
# Nathan
# <class 'str'>

# %% [markdown]
# ### Variables are case sensitive.

# %%
print(last_name)
# Out:
# Gabriel

# %% [markdown]
# ### Must refer to variables **exactly** as they were defined

# %%
print(first_name)
# Out:
# Nathan

# %% [markdown]
# ### There are many other types besides numbers and strings

# %%
import pandas as pd 

car_features = pd.read_csv('data/features.csv')
print(type(car_features))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[63], line 3
#       1 import pandas as pd
#       2
# ----> 3 car_features = pd.read_csv('data/features.csv')
#       4 print(type(car_features))
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/io/parsers/readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/io/parsers/readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/io/parsers/readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File /opt/anaconda3/lib/python3.14/site-packages/pandas/io/common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/features.csv'

# %% [markdown]
# # <span style="color:darkblue"> 3. Intro to Lists </span>
#
# ### We often want to store multiple objects inside a single named location.
#
# ### We can do so by creating "lists"
# - #### Lists are always created using square brackets [...]
# - #### The elements (items) of the list are separated by commas

# %%
# Combined list of favorite movies from section 1 and section 2

# We can hit return to continue on the next line if the current one 
# is getting too long - this is allowed in between the "[" and the "]"

favorite_movies = ["Lucy", "Lego Movie", "The Hunger Games", "Zootopia", 
                   "The Avengers", "Into the Wild", "Evil Dead (2013 remake)",
                   "Mulholland Drive", "Ghost Dog"]

print(type(favorite_movies))



for i in range(len(favorite_movies)):
    if favorite_movies[i] == "Into the Wild":
        print (i)
# Out:
# <class 'list'>
# 5

# %% [markdown]
# ### We can also count how many elements are in a list, by using the "len" (length) function

# %%
# Length of a list is the number of elements it contains
# "Elements" aka "entries" aka "components" aka "items"
print(len(favorite_movies))
# Out:
# 9

# %% [markdown]
# ## Accessing individual elements from a list
#
# - #### Use square brackets, e.g. favorite_movies[2]
# - #### Python lists always start at the **ZERO** position

# %%
print(favorite_movies)
# 1st movie in the list is "Lucy"
# Out:
# ['Lucy', 'Lego Movie', 'The Hunger Games', 'Zootopia', 'The Avengers', 'Into the Wild', 'Evil Dead (2013 remake)', 'Mulholland Drive', 'Ghost Dog']

# %%
# In Python, "Lucy" is the ZEROTH movie (movie in position 0)
print(favorite_movies[0])
print(favorite_movies[3])
# Out:
# Lucy
# Zootopia

# %% [markdown]
# ### It is often convenient to save an index to a named variable...you can use this variable to access the corresponding element of the list

# %%
# Kevin chose "Evil Dead (2013 remake)" as his favorite, which is in position *6*
peter_index = 1
# Nathan chose "Ghost Dog" as his favorite, which is in position *8*
nathan_index = 8

# %%
# We can use the variables we created in the last cell to access the 
# corresponding elements of the list

peter_fav_movie = favorite_movies[peter_index]
nathan_fav_movie = favorite_movies[nathan_index]

print(peter_fav_movie)
print(nathan_fav_movie)
# Out:
# Lego Movie
# Ghost Dog

# %%
# We can change/redefine elements of a list after we have created it.

# Once you access a single element of a list and assign it to a variable,
# the variable and the list do not affect each other:

print(nathan_fav_movie)

favorite_movies[nathan_index] = "Ghost Dog: The Way of the Samurai"

print(favorite_movies[nathan_index])
print(nathan_fav_movie)
# Out:
# Ghost Dog
# Ghost Dog: The Way of the Samurai
# Ghost Dog

# %%
print(favorite_movies)
# Out:
# ['Lucy', 'Lego Movie', 'The Hunger Games', 'Zootopia', 'The Avengers', 'Into the Wild', 'Evil Dead (2013 remake)', 'Mulholland Drive', 'Ghost Dog: The Way of the Samurai']

# %% [markdown]
# # **Warning**
#
# ### If you try to create a new variable using the assignment operator with the **entire** list, it will not make a distinct copy! They will be two different names for the same object!

# %%
# we'll make a list where each entry is a floating-point number
list_of_floats = [2.3, -1.0, 5.1, 9.9]

# Here, we are grabbing *one* element of the list, so a new variable is made
new_variable = list_of_floats[2]

print(new_variable)

list_of_floats[2] = 0.0

print(list_of_floats)
print(new_variable)
# Out:
# 5.1
# [2.3, -1.0, 0.0, 9.9]
# 5.1

# %%
list_of_floats = [2.3, -1.0, 5.1, 9.9]

# Here, we are using the *entire list* with the assignment operator, 
# so we are NOT making a distinct new variable

list_of_numbers = list_of_floats

print(list_of_numbers)

list_of_floats[2] = 0.0

print(list_of_numbers)
# Out:
# [2.3, -1.0, 5.1, 9.9]
# [2.3, -1.0, 0.0, 9.9]

# %% [markdown]
# ### Lists can have elements with different types - and you can place values from existing variables too

# %%
q = 12.1
my_list = [2, 0.1, -2, "QTM151", 3.3, "DSci151", q]
print(my_list)

# notice the last element is 12.1, and NOT the letter "q"

# %% [markdown]
# ### You can even have a list where one of the elements is itself a list

# %%
another_list = [7, 5, favorite_movies, "20", 20]
print(another_list)
print(len(another_list))

# entries are:
# -> 7 (integer)
# -> 5 (integer)
# -> favorite_movies (list we created above)
# -> the string "20" 
# -> the number 20 (an integer)

# %%
print(another_list[0])
print(another_list[1])
print(another_list[2])

# %% [markdown]
# ### Element 2 of another_list is a list itself. We can grab element 3 from the "inside" list as follows:

# %%
# another_list[2] is a list.
# To grab element 3 of a list called "name_of_list", we type: name_of_list[3]
# So to grab element 3 of another_list[2]:

print(another_list[2][3])

# %%
# Access Nathan's favorite movie
print(another_list[2][nathan_index])

# %% [markdown]
# ##### Accessing elements with negative numbers

# %%
print(favorite_movies)

# %%
print(favorite_movies[0]) # first element
print(favorite_movies[1]) # second element
print(favorite_movies[2]) # third element
print()
print(favorite_movies[-1]) # last element
print(favorite_movies[-2]) # second-to-last element
print(favorite_movies[-3]) # third-to-last element

# %% [markdown]
# ## <span style="color:darkblue">  Concatenate two or more strings </span>
#
# * ### We saw that two numbers can be added using "+"
# * ### The "+" operator can also be used on strings, which concatenates (combines) them

# %%
print("Hello World!")
print("Hello " + "World!")
print("Hello " "World" + "!")
# Out:
# Hello World!
# Hello World!
# Hello World!

# %% [markdown]
# ### You can also concatenate strings after they are stored as variables

# %%
full_name = first_name + last_name
print(full_name)
# Out:
# NathanGabriel

# %%
# What should we do if we want a space between the first and last names?
# Using the variables first_name and last_name, print "Nathan Gabriel" (with a space in between)
print(first_name + " " + last_name)
# Out:
# Nathan Gabriel

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Define a variable with your name.
# - Define a new variable with your major.
# - Print a concantenated string with your name and major

# %%
#  Write your own code here
# Print the phrase "I am [name] majoring in [major]", after defining the two variables below.

name = "Jimmy"
major = "IDK"

print("im " + name  + " i am majoring " + major)
# Out:
# im Jimmy i am majoring IDK

# %% [markdown]
# ### Lists can have lists with different types - and you can place values from existing variables too

# %%
q = 12.1
my_list = [2, 0.1, -2, "DSci185", 3.3, "DSci160", q]
print(my_list)
# Out:
# [2, 0.1, -2, 'DSci185', 3.3, 'DSci160', 12.1]

# %% [markdown]
# ### You can even have a list where one of the elements is itself a list

# %%
favorite_movies = ["Lucy", "Lego Movie", "The Hunger Games", "Zootopia", "The Avengers",
                   "Into the Wild", "Evil Dead (2013 remake)"]

another_list = [7, 5, favorite_movies, "20", 20]
print(another_list)

# entries are:
# -> 7 (integer)
# -> 5 (integer)
# -> favorite_movies (list we created above)
# -> the string "20" 
# -> the number 20 (an integer)
# Out:
# [7, 5, ['Lucy', 'Lego Movie', 'The Hunger Games', 'Zootopia', 'The Avengers', 'Into the Wild', 'Evil Dead (2013 remake)'], '20', 20]

# %%
# We would describe the integer 7 as the "first element" of another_list
# but in Python, this is the "zeroth element" of the list
print(another_list[0])

# maybe, better to say "the first element is in position 0"
# Out:
# 7

# %%
# the second element (the integer 5) is in position 1
print(another_list[1])
# Out:
# 5

# %%
# print the other elements
print(another_list[2])
print(another_list[3])
print(another_list[4])
# Out:
# ['Lucy', 'Lego Movie', 'The Hunger Games', 'Zootopia', 'The Avengers', 'Into the Wild', 'Evil Dead (2013 remake)']
# 20
# 20

# %% [markdown]
# ### You can extract a value from a list, and assign it to a new variable

# %%
grocery_list = ["apples", "bananas", "diapers", "bread", "eggs", "milk"]

grocery_item = grocery_list[4]
print(grocery_item) # what will be printed?
# Out:
# eggs

# %% [markdown]
# ##

# %% [markdown]
# #  <span style="color:darkblue"> Exercises </span>

# %% [markdown]
# ### 1) Try predicting the type of each of these expressions before running the cell. Write your prediction as a comment.

# %%
print(type(42))
# prediction: int
print(type(4.2))
# prediction: float
print(type('42'))
# prediction: str
print(type(4+2.))
# prediction: float
print(type(4/2))
# prediction: float
print(type(4//2.))
# prediction: float
print(type(len(grocery_list)))
# prediction: int
print(type(len))
# prediction: func
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'int'>
# <class 'builtin_function_or_method'>

# %% [markdown]
# ### 2) Does the code below swap the values of a and b? If not, write code that does swap their values.

# %%
a = "left"
b = "right"
c = ...



c = a
a = b
b = c

print(a,b)
# Out:
# right left

# %% [markdown]
# ### 3) Which of these are legal variable names? Predict first and then uncoment one at a time.

# %%
2nd_place = "silver"
second_place = "silver"
_second_place = "silver"
second place = "silver"
secondPlace = "silver"



print(_second_place)
# Out:
# silver

# %% [markdown]
# ### 4) Write code that creats a single list, called birthdays, containing all of the lists given in the cell below.

# %%
abed = ["Abed", "March", 23, 2007]
britta = ["Britta", "July", 14, 1998]
jeff = ["Jeff", "December", 8, 1990]
shirley = ["Shirley", "January", 19, 1990]
annie = ["Annie", "September", 27, 2007]
troy = ["Troy", "June", 5, 2007]
pierce = ["Pierce", "December", 30, 1962]

# %%
birthdays = [abed,britta,jeff,shirley,annie,troy,pierce]



print(birthdays)
# Out:
# [['Abed', 'March', 23, 2007], ['Britta', 'July', 14, 1998], ['Jeff', 'December', 8, 1990], ['Shirley', 'January', 19, 1990], ['Annie', 'September', 27, 2007], ['Troy', 'June', 5, 2007], ['Pierce', 'December', 30, 1962]]

# %% [markdown]
# ### 5) Fill in the empty brackets to print Shirley's birthday.

# %%
print("Shirley's birthday is " + str(birthdays[3][1] ) + " "+ str(birthdays[3][2]))
# Out:
# Shirley's birthday is January 19

# %% [markdown]
# ### 6) Write code that changes Shirley's birthday to Febuary 2nd. Try doing it using both positive and negative indexing.
