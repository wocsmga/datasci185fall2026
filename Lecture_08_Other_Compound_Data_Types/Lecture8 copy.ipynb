# %% [markdown]
# # <span style="color:darkblue; font-size:30px"> Lecture 8: Compound Data Types</span>

# %% [markdown]
# <font size="5">
#
# In the previous class we:
# - Learned about two kinds of indented code blocks: "for loops" and "while loops"
# - Learned about "debug mode" in Jupyter code cells
#
#
# In this class we will learn about two compound data type:
# - A compound data type is a category of data that combines multiple individual values or types into a single unit.
#   - Lists are one specific kind of compound data type in Python that we have already seen.
#   - Today we will learn about two others: `tuples`, `sets`, and numpy `arrays`.

# %% [markdown]
# ## <span style="color:darkblue"> I. Tuples </span>

# %% [markdown]
# <font size = "4">
# We'll make a list of 4 elements, then create an equivalent tuple

# %%
list_of_numbers = [5, 3, 2, 0]

tuple_of_numbers = (5, 3, 2, 0)

print(list_of_numbers)
print(tuple_of_numbers)
print()
print(type(list_of_numbers))
print(type(tuple_of_numbers))
# Out:
# [5, 3, 2, 0]
# (5, 3, 2, 0)
#
# <class 'list'>
# <class 'tuple'>

# %% [markdown]
# <font size = "4">
#
# Lists are **mutable**. This means we can change them or "mutate" them

# %%
list_of_numbers[3] = 55
print(list_of_numbers)
# Out:
# [5, 3, 2, 55]

# %% [markdown]
# <font size = "4">
#
# Tuples are **immutable**. We cannot change them once they are created.
#
# This is a good place to store values if you *know* they should never be changed.

# %%
# Can access elements of tuple just like lists
print(tuple_of_numbers[3])
# Out:
# 0

# %%
# But we cannot modify them!
tuple_of_numbers[3] = 55
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 2
#       1 # But we cannot modify them!
# ----> 2 tuple_of_numbers[3] = 55
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# <font size = "4">
#
# Strangely enough, you can create tuples without typing the parentheses explicitly...

# %%
tuple_of_numbers = 5, 3, 2, 0

print(tuple_of_numbers)
print()
print(type(tuple_of_numbers))

# %% [markdown]
# ### Concatenation
#
# <font size = "4">
#
# We already saw the "+" operator used to **concatenate** strings (Lecture 2).
#
# It also works with lists and tuples.

# %%
tuple_1 = (1, 2, 0, 9, 8)
tuple_2 = (-1, -50)

print(tuple_1 + tuple_2)
# Out:
# (1, 2, 0, 9, 8, -1, -50)

# %% [markdown]
# <font size = "4">
#
# Don't need to create variables before concatenating...

# %%
my_list = ["sequence", "Python", 1.2, 0] + [5, -3]
print(my_list)


# Do we need comma after the 1?
my_tuple = (1,) + (2, 3, 4, 5, 6, 7, 8, 9)
print(my_tuple)
# Out:
# ['sequence', 'Python', 1.2, 0, 5, -3]
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
# Yes, we need the comma after the 1!

my_tuple = (1,) + (2, 3, 4, 5, 6, 7, 8, 9)
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
# Explanation

print(type(1)) # this is an integer
print(type((1,))) # this is a tuple
# Out:
# <class 'int'>
# <class 'tuple'>

# %%
# Commas are more important than the parentheses for tuples
my_tuple = 1, + 2, 3, 4, 5, 6, 7, 8, 9
print(my_tuple)
# Out:
# (1, 2, 3, 4, 5, 6, 7, 8, 9)

# %%
# Effect of parentheses/brackets/commas when defining an object
var_1 = 1
var_2 = (1)
var_3 = (1,)
var_4 = 1,
var_5 = [1]
var_6 = [1,]

print(type(var_1))
print(type(var_2))
print(type(var_3))
print(type(var_4))
print(type(var_5))
print(type(var_6))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'tuple'>
# <class 'tuple'>
# <class 'list'>
# <class 'list'>

# %% [markdown]
# ## <span style="color:darkblue; font-size:30px">II. Sets</span>
#
# <font size = "3">
#
# A **set** is an *unordered* collection of *unique* items, ~~just~~ kind of like a set in mathematics.
# - Sets are created with curly braces `{ }`
# - A set **never contains duplicates**.
# - A set has **no order**.
# - Sets are **mutable**, like lists. We can add and remove items.

# %%
list_of_colors = ["red", "blue", "red", "green", "blue", "red"]

set_of_colors = {"red", "blue", "red", "green", "blue", "red"}

print(list_of_colors)
print(set_of_colors)
print()
print(type(list_of_colors))
print(type(set_of_colors))
# Out:
# ['red', 'blue', 'red', 'green', 'blue', 'red']
# {'blue', 'green', 'red'}
#
# <class 'list'>
# <class 'set'>

# %% [markdown]
# The duplicates are gone! Also notice that the set might not print in the order we typed it.
#
#
# Just like `np.array()` converts a list into an array, `set()` converts a list into a set. This is a quick way to find the **unique** items in a list.

# %%
# results of rolling a six-sided die 8 times
rolls = [3, 6, 1, 3, 3, 6, 2, 1]

unique_rolls = set(rolls)

print(unique_rolls)
print(len(unique_rolls), "different numbers were rolled")
# Out:
# {1, 2, 3, 6}
# 4 different numbers were rolled

# %%
# sets of whole numbers are NOT always printed in increasing order
print({10, 3, 1})
# Out:
# {1, 10, 3}

# %%
# Since a set has no order, there is no "first" item. This gives an error!
print(set_of_colors)
# Out:
# {'blue', 'green', 'red'}

# %% [markdown]
# ### Checking membership with `in`
#
# <font size = "4">
#
# Just like with lists, we can use `in` to check whether an item is in a set. The result is a Boolean.

# %%
print(set_of_colors)

print("red" in set_of_colors)
print("purple" in set_of_colors)

# %% [markdown]
# ### Adding and removing items from sets

# %%
set_of_colors.add("purple")
print(set_of_colors)

# adding an item that is already in the set does nothing
set_of_colors.add("red")
print(set_of_colors)

set_of_colors.remove("blue")
print(set_of_colors)

# %% [markdown]
# Creating an empty set

# %%
# Effect of curly braces when defining an object
var_1 = {}
var_2 = set()
var_3 = {1}

print(type(var_1))
print(type(var_2))
print(type(var_3))
# Out:
# <class 'dict'>
# <class 'set'>
# <class 'set'>

# %% [markdown]
# We will talk about dictionaries next lecture.

# %% [markdown]
# ### Set operations
#
# <font size = "4">
#
# Sets come with the same operations you may have seen in math class (think of a Venn diagram with two circles, `a` and `b`):
#
# - **Union** ($a \cup b$), written `a | b`: items in `a` **or** `b` (or both)
# - **Intersection** ($a \cap b$), written `a & b`: items in **both** `a` **and** `b`
# - **Difference** ($a \setminus b$), written `a - b`: items in `a` but **not** in `b`
#
# **Note:** use the symbols `|` and `&`, not the words `or` and `and`. The words will not give an error, but they will not give you the union or intersection either!

# %%
# the days your professor is free for office hours
prof_free = {"Monday", "Thursday", "Friday"}

# the days you are free
my_free = {"Tuesday", "Thursday", "Friday", "Saturday"}

# Intersection: days when BOTH of us are free
print(prof_free & my_free)

# Union: days when AT LEAST ONE of us is free
print(prof_free | my_free)

# Difference: days when the professor is free, but I am NOT
print(prof_free - my_free)

print(my_free-prof_free)
# Out:
# {'Friday', 'Thursday'}
# {'Friday', 'Monday', 'Tuesday', 'Saturday', 'Thursday'}
# {'Monday'}
# {'Tuesday', 'Saturday'}

# %%
# the order matters for difference!
# days when I am free, but the professor is NOT
print(my_free - prof_free)
# Out:
# {'Tuesday', 'Saturday'}

# %% [markdown]
# ### Example: counting favorite colors
#
# <font size = "4">
#
# Suppose we poll 15 people and ask their favorite color. We simply collect all 15 responses, and store them as strings inside a list. Duplicate answers correspond to duplicate entries of the list. Collecting the data like this is convenient for using `plt.hist` which creates a histogram.

# %%
import matplotlib.pyplot as plt

favorite_colors = ["red", "red", "blue", "pink", "green", "orange", "orange", "yellow",
                    "red", "green", "red", "blue", "blue", "yellow", "green"]


colors = set(favorite_colors)

count = []
num = 0

for color in list(colors):
    for i in favorite_colors:
        if i == color:
            num += 1

    count.append(num)
    num = 0


print(count)

plt.bar(list(colors),count)

plt.show()
# Out:
# [4, 2, 3, 2, 1, 3]

# %% [markdown]
# The `.index()` method for lists will be useful for demonstration

# %%
demo_list = ["first", "second", "third"]

print(demo_list.index("second"))
# Out:
# 1

# %% [markdown]
# <font size = "4">
#
# For discrete or categorical data such as this, a histogram is not really an appropriate choice (notice how orange and yellow are "stuck together").
#
# Instead we should do a bar plot. But `plt.bar` requires a list with counts of each category, which is not the way we have our data stored.
#
# We can build a list of counts as follows:

# %%
favorite_colors = ["red", "red", "blue", "pink", "green", "orange", "orange", "yellow",
                    "red", "green", "red", "blue", "blue", "yellow", "green"]

unique_colors = []
count = []

for color in favorite_colors:
    




    # your code here




    
print(unique_colors)
print(count)
# Out:
#   Cell In[13], line 14
#     print(unique_colors)
#     ^
# IndentationError: expected an indented block after 'for' statement on line 7

# %% [markdown]
# Now make a bar plot of the colors and count

# %%
plt.bar(x = unique_colors, height = count)
plt.show()

# %% [markdown]
# ## <span style="color:darkblue; font-size:30px">II. More NumPy Arrays</span>
#
# <font size = "3">

# %%
# import the library. "np" is the standard nickname
import numpy as np

# The most common way to create a Numpy array is to convert a list 
# into a numpy array.

list_of_numbers = [5.6, 2.9, 9.7, -10, 0, 3]

array_of_numbers = np.array(list_of_numbers)

print(type(array_of_numbers))
print(array_of_numbers)
display(array_of_numbers)

# %%
# creating an array of all zeros
five_zeros = np.zeros(5)
print(five_zeros)
# creating an array of all ones
ten_ones = np.ones(10)
print(ten_ones)

# %% [markdown]
# ### `np.arange(start, stop, interval)` works just like the `range` function, but for creating arrays.
#
# - it is particularly useful for plotting functions

# %%
# if you only put one argument into the arange function it is treated as the stop value with 0 as the start and 1 as the interval
zero2ten = np.arange(11)
print(zero2ten)

# %%
# two arguments are interpreted as the start and stop values
one2ten = np.arange(1, 11)
print(one2ten)

# %%
# using all three arguments
zero2ten_mod2 = np.arange(0, 11, 2)
print(zero2ten_mod2)

# %% [markdown]
# BE CAREFUL: variable assignment for arrays works just like lists

# %%
a = np.array([1, 1])
b = np.array([2, 2])

temp = a
a[0] = b[0]
b[0] = temp[0]

print(a, b)

# %% [markdown]
# ### Basic Slicing
#
# We can select a range of values using `:`.

# %%
slice = zero2ten[2:5]
print(slice)

# %%
slice[0] = 20
print(slice)

# %% [markdown]
# But look at what happened to our original array:

# %%
print(zero2ten)

# %%
# lets return zero2ten to its previous values.

zero2ten = np.arange(11)
print(zero2ten)

# %%
# this doesnt change slice, since we are taking anew object and assigning it to the zero2ten variable

print(slice)

# %% [markdown]
# You can perform element wise operations on slices just like you do with arrays.

# %%
slice = zero2ten[2:5]
print(slice)

slice = slice + np.ones(3)*10
print(slice)

# %%
# notice that the cell above didn't change the values in zero2ten
print(zero2ten)

# %% [markdown]
# ## <span style="color:darkblue"> Exercises </span>

# %% [markdown]
# #### **(1)** The array `temps` below contains the daily high temperatures (in °F) for one week, starting on Sunday and ending on Saturday.
#
# <font size = "4">
#
# - Use negative indexing to print Saturday's temperature
# - Use a slice to print the temperatures for Monday through Friday
# - Try using a slice with a negative index to print the temperatures for Friday and Saturday

# %%
temps = np.array([71, 68, 74, 80, 77, 65, 69])

# your code here

# %% [markdown]
# #### (2) Before running the cell below, predict what will be printed. Then run it to check your prediction.
#
# <font size = "4">
#
# - Explain why `scores` changed but `backup` did not.
# - Change one line of the code so that `scores` is not modified.

# %%
scores = np.array([90, 85, 70, 100])

backup = scores.copy()
first_two = scores[0:2]

first_two[1] = 0

print(scores)
print(backup)
print(first_two)

# %% [markdown]
# #### (3) In Lecture 4 we saw the list method `.count()`, which counts how many times an item appears in a list. Rewrite the favorite colors example from Section II so that it uses `.count()` instead of `.index()`.
#
# <font size = "4">
#
# *Hint:* loop over the unique colors, instead of over all 15 responses.
